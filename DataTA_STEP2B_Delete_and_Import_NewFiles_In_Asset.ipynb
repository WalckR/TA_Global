# %%
##########################################################################################################################################
####################### This script deletes previous files in the GEE asset and uploads new ones from disc ##############################
#################### Please check the Task Manager from the JavaScript Code Editor toi ensure files are uploaded ########################
##########################################################################################################################################

# %%
import ee # Import the Python API package
import geemap # The geemap Python package is built upon the ipyleaflet and folium packages and implements several methods for interacting with Earth Engine data layer
try:
    ee.Initialize(project='amibea') # Initialize the API
except Exception as e:
    ee.Authenticate() # Authenticate to the Earth Engine servers
    ee.Initialize(project='amibea') # Initialize the API

print(ee.data.getAssetRoots())
# Out:
# C:\python\anaconda3\envs\Amibea\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# [{'type': 'Folder', 'id': 'projects/amibea/assets/CLUSTER1'}, {'type': 'Folder', 'id': 'projects/amibea/assets/CLUSTER2'}, {'type': 'Folder', 'id': 'projects/amibea/assets/CLUSTER3'}, {'type': 'Folder', 'id': 'projects/amibea/assets/DIVERSITY'}, {'type': 'Folder', 'id': 'projects/amibea/assets/RICHNESS'}, {'type': 'Table', 'id': 'projects/amibea/assets/TA_Clusters_GEEformated_2026'}, {'type': 'Table', 'id': 'projects/amibea/assets/TA_Diversity_GEEformated_2026'}, {'type': 'Table', 'id': 'projects/amibea/assets/TA_Richness_GEEformated_2026'}]

# %%
# Liste des assets à supprimer avant de commencer
assets_to_delete = [
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_0_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_1_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_2_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_3_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_4_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_5_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_6_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_7_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_8_GEE',
    'projects/amibea/assets/CLUSTER1/TrainPts_Run_9_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_0_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_1_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_2_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_3_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_4_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_5_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_6_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_7_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_8_GEE',
    'projects/amibea/assets/CLUSTER2/TrainPts_Run_9_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_0_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_1_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_2_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_3_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_4_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_5_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_6_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_7_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_8_GEE',
    'projects/amibea/assets/CLUSTER3/TrainPts_Run_9_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_0_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_1_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_2_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_3_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_4_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_5_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_6_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_7_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_8_GEE',
    'projects/amibea/assets/DIVERSITY/TrainPts_Run_9_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_0_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_1_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_2_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_3_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_4_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_5_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_6_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_7_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_8_GEE',
    'projects/amibea/assets/RICHNESS/TrainPts_Run_9_GEE',
]

for asset in assets_to_delete:
    try:
        ee.data.deleteAsset(asset)
        print(f"Supprimé : {asset}")
    except:
        print(f"Asset non trouvé ou déjà supprimé : {asset}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Supprimé : projects/amibea/assets/CLUSTER1/TrainPts_Run_0_GEE
# Supprimé : projects/amibea/assets/CLUSTER1/TrainPts_Run_1_GEE
# Supprimé : projects/amibea/assets/CLUSTER1/TrainPts_Run_2_GEE
# ...

# %%
# Load data points from disc to drive and to asset
# Cluster1
fc0 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_0_GEE.csv")
geemap.ee_export_vector_to_asset(fc0, description='Export_Cluster1_Run_0', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_0_GEE')

fc1 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_1_GEE.csv")
geemap.ee_export_vector_to_asset(fc1, description='Export_Cluster1_Run_1', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_1_GEE')

fc2 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_2_GEE.csv")
geemap.ee_export_vector_to_asset(fc2, description='Export_Cluster1_Run_2', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_2_GEE')

fc3 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_3_GEE.csv")
geemap.ee_export_vector_to_asset(fc3, description='Export_Cluster1_Run_3', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_3_GEE')

fc4 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_4_GEE.csv")
geemap.ee_export_vector_to_asset(fc4, description='Export_Cluster1_Run_4', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_4_GEE')

fc5 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_5_GEE.csv")
geemap.ee_export_vector_to_asset(fc5, description='Export_Cluster1_Run_5', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_5_GEE')

fc6 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_6_GEE.csv") 
geemap.ee_export_vector_to_asset(fc6, description='Export_Cluster1_Run_6', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_6_GEE')

fc7 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_7_GEE.csv")
geemap.ee_export_vector_to_asset(fc7, description='Export_Cluster1_Run_7', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_7_GEE')

fc8 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_8_GEE.csv")
geemap.ee_export_vector_to_asset(fc8, description='Export_Cluster1_Run_8', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_8_GEE')

fc9 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster1\TrainPts_Run_9_GEE.csv")
geemap.ee_export_vector_to_asset(fc9, description='Export_Cluster1_Run_9', assetId='projects/amibea/assets/CLUSTER1/TrainPts_Run_9_GEE')

# Cluster2
fc10 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_0_GEE.csv")
geemap.ee_export_vector_to_asset(fc10, description='Export_Cluster2_Run_0', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_0_GEE')

fc11 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_1_GEE.csv")
geemap.ee_export_vector_to_asset(fc11, description='Export_Cluster2_Run_1', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_1_GEE')

fc12 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_2_GEE.csv")
geemap.ee_export_vector_to_asset(fc12, description='Export_Cluster2_Run_2', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_2_GEE')

fc13 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_3_GEE.csv")
geemap.ee_export_vector_to_asset(fc13, description='Export_Cluster2_Run_3', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_3_GEE')

fc14= geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_4_GEE.csv")
geemap.ee_export_vector_to_asset(fc14, description='Export_Cluster2_Run_4', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_4_GEE')

fc15 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_5_GEE.csv")
geemap.ee_export_vector_to_asset(fc15, description='Export_Cluster2_Run_5', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_5_GEE')

fc16 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_6_GEE.csv")
geemap.ee_export_vector_to_asset(fc16, description='Export_Cluster2_Run_6', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_6_GEE')

fc17 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_7_GEE.csv")
geemap.ee_export_vector_to_asset(fc17, description='Export_Cluster2_Run_7', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_7_GEE')

fc18 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_8_GEE.csv")
geemap.ee_export_vector_to_asset(fc18, description='Export_Cluster2_Run_8', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_8_GEE')

fc19 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster2\TrainPts_Run_9_GEE.csv")
geemap.ee_export_vector_to_asset(fc19, description='Export_Cluster2_Run_9', assetId='projects/amibea/assets/CLUSTER2/TrainPts_Run_9_GEE')

# Cluster3
fc20 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_0_GEE.csv")
geemap.ee_export_vector_to_asset(fc20, description='Export_Cluster3_Run_0', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_0_GEE')

fc21 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_1_GEE.csv")
geemap.ee_export_vector_to_asset(fc21, description='Export_Cluster3_Run_1', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_1_GEE')

fc22 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_2_GEE.csv")
geemap.ee_export_vector_to_asset(fc22, description='Export_Cluster3_Run_2', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_2_GEE')

fc23 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_3_GEE.csv")
geemap.ee_export_vector_to_asset(fc23, description='Export_Cluster3_Run_3', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_3_GEE')

fc24 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_4_GEE.csv")
geemap.ee_export_vector_to_asset(fc24, description='Export_Cluster3_Run_4', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_4_GEE')

fc25 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_5_GEE.csv")
geemap.ee_export_vector_to_asset(fc25, description='Export_Cluster3_Run_5', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_5_GEE')

fc26 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_6_GEE.csv")
geemap.ee_export_vector_to_asset(fc26, description='Export_Cluster3_Run_6', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_6_GEE')

fc27 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_7_GEE.csv")
geemap.ee_export_vector_to_asset(fc27, description='Export_Cluster3_Run_7', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_7_GEE')

fc28 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_8_GEE.csv")
geemap.ee_export_vector_to_asset(fc28, description='Export_Cluster3_Run_8', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_8_GEE')

fc29 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Clusters\Cluster3\TrainPts_Run_9_GEE.csv")
geemap.ee_export_vector_to_asset(fc29, description='Export_Cluster3_Run_9', assetId='projects/amibea/assets/CLUSTER3/TrainPts_Run_9_GEE')

# Diversity
fc30 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_0_GEE.csv")
geemap.ee_export_vector_to_asset(fc30, description='Export_Diversity_Run_0', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_0_GEE')

fc31 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_1_GEE.csv")
geemap.ee_export_vector_to_asset(fc31, description='Export_Diversity_Run_1', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_1_GEE')

fc32 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_2_GEE.csv")
geemap.ee_export_vector_to_asset(fc32, description='Export_Diversity_Run_2', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_2_GEE')

fc33 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_3_GEE.csv")
geemap.ee_export_vector_to_asset(fc33, description='Export_Diversity_Run_3', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_3_GEE')

fc34 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_4_GEE.csv")
geemap.ee_export_vector_to_asset(fc34, description='Export_Diversity_Run_4', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_4_GEE')

fc35 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_5_GEE.csv")
geemap.ee_export_vector_to_asset(fc35, description='Export_Diversity_Run_5', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_5_GEE')

fc36 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_6_GEE.csv")
geemap.ee_export_vector_to_asset(fc36, description='Export_Diversity_Run_6', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_6_GEE')

fc37 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_7_GEE.csv")
geemap.ee_export_vector_to_asset(fc37, description='Export_Diversity_Run_7', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_7_GEE')

fc38 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_8_GEE.csv")
geemap.ee_export_vector_to_asset(fc38, description='Export_Diversity_Run_8', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_8_GEE')

fc39 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Diversity\TrainPts_Run_9_GEE.csv")
geemap.ee_export_vector_to_asset(fc39, description='Export_Diversity_Run_9', assetId='projects/amibea/assets/DIVERSITY/TrainPts_Run_9_GEE')

# Richness
fc40 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_0_GEE.csv")
geemap.ee_export_vector_to_asset(fc40, description='Export_Richness_Run_0', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_0_GEE')

fc41 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_1_GEE.csv")
geemap.ee_export_vector_to_asset(fc41, description='Export_Richness_Run_1', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_1_GEE')

fc42 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_2_GEE.csv")
geemap.ee_export_vector_to_asset(fc42, description='Export_Richness_Run_2', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_2_GEE')

fc43 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_3_GEE.csv")
geemap.ee_export_vector_to_asset(fc43, description='Export_Richness_Run_3', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_3_GEE')

fc44 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_4_GEE.csv")
geemap.ee_export_vector_to_asset(fc44, description='Export_Richness_Run_4', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_4_GEE')

fc45 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_5_GEE.csv")
geemap.ee_export_vector_to_asset(fc45, description='Export_Richness_Run_5', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_5_GEE')

fc46 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_6_GEE.csv")
geemap.ee_export_vector_to_asset(fc46, description='Export_Richness_Run_6', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_6_GEE')

fc47 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_7_GEE.csv")
geemap.ee_export_vector_to_asset(fc47, description='Export_Richness_Run_7', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_7_GEE')

fc48 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_8_GEE.csv")
geemap.ee_export_vector_to_asset(fc48, description='Export_Richness_Run_8', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_8_GEE')

fc49 = geemap.csv_to_ee(in_csv=r"E:\Amibatec\Updated2026\RF\Richness\TrainPts_Run_9_GEE.csv")
geemap.ee_export_vector_to_asset(fc49, description='Export_Richness_Run_9', assetId='projects/amibea/assets/RICHNESS/TrainPts_Run_9_GEE')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# projects/amibea/assets/CLUSTER1/TrainPts_Run_0_GEE
# Exporting Export_Cluster1_Run_0... Please check the Task Manager from the JavaScript Code Editor.
# projects/amibea/assets/CLUSTER1/TrainPts_Run_1_GEE
# ...
